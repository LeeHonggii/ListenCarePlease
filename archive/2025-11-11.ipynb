# %%
# 필수 라이브러리 설치
# !pip install faster-whisper
# !pip install torch torchaudio
# !pip install librosa
# !pip install jiwer  # CER 계산용
# Out:
# Collecting faster-whisper
#   Downloading faster_whisper-1.2.1-py3-none-any.whl.metadata (16 kB)
# Collecting ctranslate2<5,>=4.0 (from faster-whisper)
#   Downloading ctranslate2-4.6.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: huggingface-hub>=0.21 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.36.0)
# Requirement already satisfied: tokenizers<1,>=0.13 in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (0.22.1)
# Collecting onnxruntime<2,>=1.14 (from faster-whisper)
#   Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Collecting av>=11 (from faster-whisper)
#   Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from faster-whisper) (4.67.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (2.0.2)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.12/dist-packages (from ctranslate2<5,>=4.0->faster-whisper) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21->faster-whisper) (1.2.0)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (25.9.23)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.13.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21->faster-whisper) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21->faster-whisper) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21->faster-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21->faster-whisper) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Downloading faster_whisper-1.2.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 60.3 MB/s eta 0:00:00
# Downloading av-16.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (40.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 57.5 MB/s eta 0:00:00
# Downloading ctranslate2-4.6.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (38.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 66.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.23.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 118.0 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.0 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, ctranslate2, av, coloredlogs, onnxruntime, faster-whisper
# Successfully installed av-16.0.1 coloredlogs-15.0.1 ctranslate2-4.6.1 faster-whisper-1.2.1 humanfriendly-10.0 onnxruntime-1.23.2
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from librosa) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa) (1.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa) (2.32.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.10.5)
# Collecting jiwer
#   Downloading jiwer-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from jiwer) (8.3.0)
# Collecting rapidfuzz>=3.9.7 (from jiwer)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Downloading jiwer-4.0.0-py3-none-any.whl (23 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 104.8 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-4.0.0 rapidfuzz-3.14.3

# %%
# !pip install noisereduce
# Out:
# Collecting noisereduce
#   Downloading noisereduce-3.0.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from noisereduce) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from noisereduce) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from noisereduce) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from noisereduce) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from noisereduce) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->noisereduce) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.17.0)
# Downloading noisereduce-3.0.3-py3-none-any.whl (22 kB)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-3.0.3

# %%
import torch
import librosa
import numpy as np
from faster_whisper import WhisperModel
from jiwer import cer
import soundfile as sf

# %%
# Whisper large-v3 모델 로드
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"사용 디바이스: {device}")

model = WhisperModel(
    "large-v3",
    device=device,
    compute_type="float16" if device == "cuda" else "int8"
)
print("모델 로드 완료!")
# Out:
# 사용 디바이스: cuda
# tokenizer.json: 0.00B [00:00, ?B/s]
# vocabulary.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/340 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# 모델 로드 완료!

# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# 오디오 로드
audio_path = "/content/애슐리_소음.m4a"  # 여기에 실제 파일 경로 입력
audio, sr = librosa.load(audio_path, sr=16000)

# 기본 정보
print(f"오디오 길이: {len(audio) / sr:.2f}초")
print(f"최대 진폭: {np.max(np.abs(audio)):.4f}")
print(f"평균 진폭: {np.mean(np.abs(audio)):.4f}")
print(f"RMS 에너지: {np.sqrt(np.mean(audio**2)):.4f}")

# 진폭이 0.01 미만이면 매우 조용함
if np.max(np.abs(audio)) < 0.01:
    print("⚠️ 경고: 오디오가 너무 조용합니다!")
# Out:
# /tmp/ipython-input-1020891952.py:7: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(audio_path, sr=16000)
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# 오디오 길이: 2521.22초
# 최대 진폭: 1.0066
# 평균 진폭: 0.0623
# RMS 에너지: 0.0873

# %%
# 파형 시각화
plt.figure(figsize=(15, 4))
time = np.linspace(0, len(audio) / sr, len(audio))
plt.plot(time, audio)
plt.xlabel('시간 (초)')
plt.ylabel('진폭')
plt.title('오디오 파형')
plt.grid(True)
plt.show()

# 음성 구간 확인
plt.figure(figsize=(15, 4))
energy = librosa.feature.rms(y=audio)[0]
times = librosa.times_like(energy, sr=sr)
plt.plot(times, energy)
plt.xlabel('시간 (초)')
plt.ylabel('RMS 에너지')
plt.title('오디오 에너지 (음성 구간 확인)')
plt.axhline(y=0.01, color='r', linestyle='--', label='임계값')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54805 (\N{HANGUL SYLLABLE HYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45320 (\N{HANGUL SYLLABLE NEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46356 (\N{HANGUL SYLLABLE DI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 52488 (\N{HANGUL SYLLABLE CO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51076 (\N{HANGUL SYLLABLE IM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import noisereduce as nr
import soundfile as sf
import librosa
import numpy as np

# 오디오 로드
audio_path = "/content/애슐리_소음.m4a"  # 여기에 실제 파일 경로 입력
audio, sr = librosa.load(audio_path, sr=16000)

print("원본 오디오:")
print(f"  RMS 에너지: {np.sqrt(np.mean(audio**2)):.4f}")

# 노이즈 프로파일 추정 (처음 2초를 노이즈로 가정)
noise_sample = audio[:sr*2]  # 처음 2초

# 노이즈 제거
audio_denoised = nr.reduce_noise(
    y=audio,
    sr=sr,
    y_noise=noise_sample,  # 노이즈 샘플
    prop_decrease=0.8,  # 80% 제거
    stationary=False,  # 비정적 노이즈 (식사 소리 등)
    freq_mask_smooth_hz=500,
    time_mask_smooth_ms=50
)

print("노이즈 제거 후:")
print(f"  RMS 에너지: {np.sqrt(np.mean(audio_denoised**2)):.4f}")

# 저장
denoised_path = "denoised_audio.wav"
sf.write(denoised_path, audio_denoised, sr)
print(f"저장 완료: {denoised_path}")
# Out:
# /tmp/ipython-input-602996982.py:8: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(audio_path, sr=16000)
# /usr/local/lib/python3.12/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# 원본 오디오:
#   RMS 에너지: 0.0873
# 노이즈 제거 후:
#   RMS 에너지: 0.0292
# 저장 완료: denoised_audio.wav

# %%
from faster_whisper import WhisperModel

model = WhisperModel("large-v3", device="cuda", compute_type="float16")

# 실제로 지원되는 파라미터만 사용
segments, info = model.transcribe(
    denoised_path,
    language="ko",

    # 환청 방지 - 지원되는 파라미터만
    condition_on_previous_text=False,  # 핵심!

    # VAD 파라미터 강화
    vad_filter=True,
    vad_parameters=dict(
        threshold=0.6,  # 더 엄격하게
        min_speech_duration_ms=500,
        min_silence_duration_ms=1000
    ),

    # 기본 파라미터
    beam_size=10,
    temperature=0.0,
    word_timestamps=True
)

print("=== 노이즈 제거 + 강력한 VAD 전사 ===")
valid_segments = []
for segment in segments:
    # 수동으로 품질 필터링
    # no_speech_prob과 avg_logprob로 필터링
    if hasattr(segment, 'no_speech_prob') and hasattr(segment, 'avg_logprob'):
        if segment.no_speech_prob < 0.7 and segment.avg_logprob > -0.8:
            print(f"[{segment.start:.2f}s -> {segment.end:.2f}s] {segment.text}")
            print(f"  신뢰도 - 무음: {segment.no_speech_prob:.2f}, 로그확률: {segment.avg_logprob:.2f}")
            valid_segments.append(segment)
    else:
        # 속성이 없으면 일단 포함
        print(f"[{segment.start:.2f}s -> {segment.end:.2f}s] {segment.text}")
        valid_segments.append(segment)

print(f"\n총 {len(valid_segments)}개의 유효한 세그먼트")
# Out:
# === 노이즈 제거 + 강력한 VAD 전사 ===
# [3.44s -> 26.88s]  아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아
#   신뢰도 - 무음: 0.10, 로그확률: -0.09
# [30.85s -> 33.05s]  기훈님은 원래 어떻게 드시나요?
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [33.45s -> 35.27s]  저 예전에 오는 기억이 없더라고요
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [64.67s -> 80.24s]  아 못 들어가지 싶어요
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [80.94s -> 98.80s]  모일 때마다 나와요
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [98.80s -> 99.82s]  습해지네요
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [99.82s -> 100.58s]  너무 맛있어요
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [101.46s -> 102.34s]  어떤 시간에 먹어요?
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [102.38s -> 104.02s]  딸기 많이 먹어야 된다는 생각이 들어요
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [104.02s -> 105.28s]  1시간이면 충분하지 않아요?
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [105.48s -> 110.13s]  저는 항상 술 꽉 채우고 나와요
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [110.87s -> 113.99s]  1시간 50분까지 먹을 건데요?
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [116.38s -> 117.36s]  저희 몇 시까지 먹는 거예요?
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [117.44s -> 118.44s]  1시간 50분까지요
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [118.88s -> 120.56s]  근데 진짜 그렇게 먹을 수 있어요?
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [120.82s -> 121.18s]  아니요
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [121.18s -> 137.05s]  지금 녹음하고 있는 거예요?
#   신뢰도 - 무음: 0.14, 로그확률: -0.47
# [137.05s -> 138.25s]  네
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [138.89s -> 146.53s]  안 될 것 같은데 마이크로 찍었잖아요
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [147.68s -> 149.28s]  모양이 명확하게 있어가지고
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [149.28s -> 149.82s]  아
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [151.44s -> 157.64s]  이거 눌러먹는 거 아니에요?
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [158.76s -> 175.20s]  진짜 행복해
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [175.20s -> 176.88s]  얼굴이 행복해 보여요
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [176.88s -> 180.19s]  진짜 많이 하거든요
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [226.98s -> 229.32s]  생각보다 자리가 금방 나서 다행인 것 같아요
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [229.32s -> 240.05s]  생각보다 사람이 많대요
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [240.87s -> 241.37s]  평일인데
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [241.37s -> 244.92s]  우리 같은 사람들이 많지 않을까요?
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [244.96s -> 245.90s]  그냥 밥 먹으러
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [245.90s -> 296.50s]  그러니 야채는 드시네요
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [296.50s -> 297.38s]  편의점 많지
#   신뢰도 - 무음: 0.22, 로그확률: -0.36
# [297.38s -> 300.06s]  입 잘 따고 하시길래 야채도 안 먹었어요 진짜로
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [300.06s -> 302.40s]  야채는 먹어요 원래 안 먹었는데
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [304.24s -> 304.92s]  먹어야겠더라구요
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [304.92s -> 310.20s]  저도 그러고 있어요
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [310.20s -> 311.78s]  야채하고 과일
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [311.78s -> 314.10s]  근데 과일은 원래 항상 좋아
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [317.08s -> 319.00s]  근데 혼자 살면 잘 안 먹게 되지 않아요?
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [320.27s -> 321.95s]  동가가 진짜 엄청 많고
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [321.95s -> 333.32s]  고댄찌개집 갔으면 저 슬플 뻔 했잖아요 성현님
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [333.32s -> 336.40s]  고댄찌개집 갔으면 저 슬플 뻔 했잖아요
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [338.50s -> 339.90s]  고댄찌개 가다고 했나요 제가?
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [340.28s -> 340.96s]  처음에
#   신뢰도 - 무음: 0.18, 로그확률: -0.29
# [340.96s -> 353.70s]  아니 지금 얼굴에 웃음이 끊이지가 않으세요
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [377.42s -> 378.26s]  본가가 못 가요?
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [378.78s -> 385.14s]  뭘 못 가요?
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [385.22s -> 385.94s]  본가요
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [386.81s -> 387.71s]  왜 못 가요?
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [388.46s -> 389.18s]  멀어서
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [389.78s -> 393.94s]  갈 때마다 본가 갈 때 가요
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [395.76s -> 397.56s]  본가 갈 때마다 먹어야죠
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [397.56s -> 399.26s]  지금 좋은데 먹어요
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [399.26s -> 401.92s]  과일은 원래 더 안 먹어요
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [402.52s -> 405.42s]  본가 가면 거의 집에 과일이 많아서
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [405.42s -> 408.44s]  1년에 한두 번 밖에 안 가요
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [409.69s -> 410.23s]  왜요?
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [410.51s -> 412.89s]  저도 한두 번 밖에 안 가서 할만해요
#   신뢰도 - 무음: 0.15, 로그확률: -0.42
# [412.89s -> 417.57s]  거리가 머시니까 조금더
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [419.36s -> 420.40s]  얼마있죠?
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [420.56s -> 421.28s]  마치 차타요
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [423.24s -> 424.38s]  근데 차타가 어디에요?
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [427.35s -> 428.97s]  차타가 30분이어서
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [428.97s -> 430.29s]  아 그럼 자주 와야겠다
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [430.90s -> 434.50s]  귀찮은데 안오면 껍껍해하셔서 가요
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [441.13s -> 442.71s]  전화 자주하면 그만하래요
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [443.21s -> 444.57s]  얼마나 자주 하세요 지금?
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [444.75s -> 447.55s]  2-3일 한 번씩 했더니 자주 아니면 그만하래
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [447.79s -> 448.89s]  할 말 없겠네
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [453.12s -> 454.38s]  그냥 안부전화가
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [454.78s -> 461.04s]  밥 먹었나? 밥 먹었대요
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [463.41s -> 465.79s]  오늘 뭐했는데? 오늘 뭐 회사 갔다왔지 끝
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [467.78s -> 468.98s]  밥 뭐 먹었는데?
#   신뢰도 - 무음: 0.21, 로그확률: -0.45
# [468.98s -> 473.54s]  나 집에 있는거 먹어봤다
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [473.54s -> 475.48s]  집에 있는거 뭐 먹었냐?
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [481.84s -> 483.42s]  엄마랑 딸이 치전데
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [485.26s -> 486.86s]  원래 반대로 물어보는게 맞지?
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [488.03s -> 490.49s]  바뀌었어요 엄마 바뀌어서
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [490.49s -> 492.11s]  집에 일찍 가라 해서
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [492.11s -> 496.88s]  사람이 외동이라고 하시네
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [496.88s -> 497.88s]  아니요 오빠 하나 있어요
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [498.90s -> 500.66s]  봐주실래요?
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [501.91s -> 503.53s]  오빠는 못봐 보네
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [503.53s -> 504.91s]  오빠랑 사이 안좋아요
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [504.91s -> 506.51s]  아니요 안좋은데 좋아요
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [506.51s -> 508.45s]  뭔지 알아요?
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [510.66s -> 516.08s]  냄새가 안나요
#   신뢰도 - 무음: 0.15, 로그확률: -0.41
# [516.08s -> 523.17s]  실수 따까리
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [523.17s -> 524.27s]  형 있어요?
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [524.65s -> 527.11s]  저도 동네인데 저는 성격이 더러워서
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [527.97s -> 529.96s]  뭘 시키면 싸웠어요
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [529.96s -> 538.32s]  너도 오빠 있어요?
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [538.58s -> 538.92s]  네
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [539.78s -> 540.40s]  따까리에요?
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [540.80s -> 541.86s]  아니요 오빠랑 안 친해요
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [544.28s -> 545.34s]  아 짱 맛있어
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [545.34s -> 551.78s]  그냥 명절이나 이벤트 때 보는 사람 아니에요?
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [552.02s -> 552.44s]  맞아요
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [552.44s -> 559.26s]  근데 사실 형도 주식하고 저도 그러고 있으니까
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [559.64s -> 560.74s]  거의 안 만나시던데요
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [560.74s -> 561.16s]  네
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [570.00s -> 570.70s]  1년에 한 번?
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [570.96s -> 573.14s]  두 번? 그렇게 안 만나요
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [573.68s -> 574.96s]  근데 형 일본이 있어요
#   신뢰도 - 무음: 0.22, 로그확률: -0.32
# [574.96s -> 592.00s]  일본은 그냥 음식이 다 맛있던데요 저는
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [592.00s -> 593.22s]  저도 좀 그런거 같아요
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [600.71s -> 602.17s]  근데 저희 형도 입이 좀 까다로워서
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [602.17s -> 605.05s]  저는 진짜 아무거나 준비를 못하거든요
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [605.05s -> 607.63s]  근데 형이 좀 까다로워가지고
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [608.03s -> 610.33s]  알아서 맛집 차려놓고 직접 끌고 다닙니다
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [610.33s -> 613.90s]  여러분 김말이 매워요?
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [614.68s -> 615.54s]  그렇게 안 매워
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [616.36s -> 617.16s]  질려가지고
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [618.10s -> 621.30s]  뭐 드세요?
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [621.80s -> 623.10s]  매운 걸 잘 못 먹어요
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [624.27s -> 624.73s]  음...
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [625.55s -> 626.65s]  인생 절반쯤 해보자
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [632.64s -> 635.04s]  4세트 김치 진짜 맛있어
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [635.04s -> 636.78s]  진짜 진짜 짱 맛있어
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [636.78s -> 637.48s]  뭐가 맛있다고요?
#   신뢰도 - 무음: 0.07, 로그확률: -0.47
# [637.48s -> 650.08s]  완전 상쾌해
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [650.08s -> 665.46s]  아침에 도랑매 안 드시길래 밥 끓인 줄 알았어요
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [665.46s -> 666.22s]  저도
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [666.64s -> 668.74s]  밥 끓인 줄 알았어요
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [677.80s -> 679.44s]  약속이 취소되는지 알았나봐요
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [679.44s -> 683.85s]  오후에 다 갔다 와야 돼가지고
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [685.13s -> 687.43s]  도랑님 늦으신 거 한 번도 못 본 거 같은데
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [687.43s -> 690.23s]  예전에 늦게 왔어요
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [690.23s -> 691.72s]  아 그래요?
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [695.68s -> 697.86s]  나왔는데 집에 투명점을 주고 온 거
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [723.24s -> 724.28s]  저한테 치는 거죠
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [724.28s -> 724.78s]  네
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [751.88s -> 754.04s]  전 집에 있는 것도 좋아해요
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [754.04s -> 755.06s]  네 감사하세요
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [756.89s -> 757.53s]  대게요?
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [757.87s -> 758.93s]  아 해외요?
#   신뢰도 - 무음: 0.20, 로그확률: -0.47
# [758.93s -> 762.18s]  다 말을 못 알아듣지. 내가 말하면 된다.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [766.30s -> 775.94s]  운이 없어 봐.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [776.94s -> 782.27s]  저도 형이 계속 일본 오라고 하는데 운이 없어 봐.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [790.33s -> 790.97s]  맞아요.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [792.57s -> 795.11s]  비행기를 좀 무서워해서.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [796.82s -> 797.90s]  비행기 무서워요.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [799.00s -> 799.92s]  그럼 해외항 가보세요.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [800.32s -> 807.76s]  비행기 타고 갔는데 비행기 탈 때 청시만 먹었어요.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [808.08s -> 821.56s]  비행기 타가지고 일단 서울 왔다 갔다 보니까 비행기가 더 싸요.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [828.65s -> 830.51s]  진짜 국내에서는 한 번도 안 타봤는데.
#   신뢰도 - 무음: 0.27, 로그확률: -0.42
# [831.15s -> 832.75s]  동네에서 만드셨나요?
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [833.91s -> 834.95s]  네, 만드셨어요
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [834.95s -> 837.59s]  근데 저는 지금 공항 앞이어서
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [837.59s -> 873.50s]  위에서 많이 못 먹어서 너무 슬퍼요
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [873.50s -> 875.00s]  안 먹으면 되죠
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [886.90s -> 887.32s]  배불러서요?
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [887.82s -> 892.74s]  약간 병원 가야겠다
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [892.74s -> 905.73s]  오전에 최대한 많이 하지 못했는데
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [905.73s -> 925.58s]  형님 말을 어렵게 하셔서
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [925.58s -> 927.52s]  많이 배우셔가지고
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [927.52s -> 928.42s]  형님이 말을
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [938.56s -> 940.92s]  짓다 마저도 제가 처리해 드릴게요
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [940.92s -> 941.28s]  아 그래요?
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [942.64s -> 945.22s]  욕하기 아니라 그냥
#   신뢰도 - 무음: 0.13, 로그확률: -0.50
# [945.22s -> 946.68s]  내 스타일이 다르다
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [946.96s -> 953.49s]  진짜 굴러 먹는 것 같은데 어떡하죠?
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [954.17s -> 955.21s]  이게 욕이지
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [955.45s -> 961.50s]  전 사장님이 이게 좀 웃겨
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [963.45s -> 964.33s]  짜증나
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [964.33s -> 971.18s]  근데 확실히 좀 말이 어렵게 해준다고 교수님들 보면
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [971.18s -> 978.64s]  그리고 일할 때도 보면은 자꾸 그냥 자기가 뜯은 언어들
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [978.90s -> 980.02s]  용어 그런 거 쓰고
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [987.64s -> 989.82s]  맥앤치즈가 진짜 맛있는데
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [990.02s -> 991.58s]  그래서 이번에 가져왔어요
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [992.20s -> 992.72s]  바질튀김도
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [992.72s -> 1000.38s]  제가 많이 못 먹어요
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [1000.48s -> 1003.83s]  너무 슬퍼요
#   신뢰도 - 무음: 0.08, 로그확률: -0.38
# [1006.59s -> 1008.25s]  나도 먹는 게 좀 줄어가지고
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1008.25s -> 1009.33s]  저희는 이렇게 땡겨요
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1009.33s -> 1010.88s]  이렇게 땋아서
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1011.44s -> 1013.72s]  저희는 많이 먹어야 돼요
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1013.72s -> 1014.40s]  성장기라서
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1014.40s -> 1022.68s]  여기서 더 커지면 징그러울 것 같은데 이제
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1030.34s -> 1031.56s]  어? 더 커보이는데?
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1032.56s -> 1033.64s]  반울림해서 좀
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1033.64s -> 1037.20s]  그냥 반울림하고 말하고 다녔는데
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1037.52s -> 1040.04s]  아 이거 덩치가 있어서 그런가
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1040.04s -> 1041.18s]  더 커보이긴 하는데
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1042.48s -> 1047.31s]  저도 반울림하면 160이에요
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1050.23s -> 1051.37s]  이때 더 커져요
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1051.37s -> 1051.85s]  어디가 더 커?
#   신뢰도 - 무음: 0.09, 로그확률: -0.55
# [1051.85s -> 1054.45s]  아니 센치 끝났어
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1054.45s -> 1056.01s]  진짜 중반까지 면치진거지
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1056.01s -> 1056.77s]  응?
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1056.89s -> 1058.29s]  진짜 중반까지 면치진거지
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1058.29s -> 1062.56s]  진짜 성장기라니까요
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1062.56s -> 1067.56s]  나 신고때 33인가 그랬는데
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1068.24s -> 1069.84s]  전역할때 입학할때 그거
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1069.84s -> 1075.36s]  아니 허리를 안추고 다니셔
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1075.36s -> 1079.56s]  아니 허리를 안추고 다니셔
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1079.56s -> 1079.98s]  힘들어
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1079.98s -> 1081.54s]  그럼 겨누리세요
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1110.72s -> 1112.35s]  그거 먹어도 더 먹을 수 있어요?
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1112.51s -> 1114.51s]  이거 먹어도 더 먹을 수 있어요?
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1114.69s -> 1125.83s]  뭔가 더 먹을 수 있을거 같다고 물어본거에요
#   신뢰도 - 무음: 0.13, 로그확률: -0.47
# [1129.41s -> 1131.01s]  저녁에도 회식이 있잖아요
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1131.01s -> 1136.58s]  근데 거기서는 좀 술 마시는 거 아니에요?
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1138.54s -> 1140.32s]  술을 좋아할 수 있는 분들이 없어서
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1140.32s -> 1148.16s]  대사에 도출받아 봐
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1148.16s -> 1162.72s]  개인 역량이긴 한데
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1172.14s -> 1172.84s]  정해볼까 봐
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1172.84s -> 1174.72s]  한 병까진 괜찮습니다
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1186.88s -> 1188.22s]  저도 한 병 반?
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1192.32s -> 1193.96s]  술 먹는 걸 좋아해가지고
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1196.82s -> 1199.12s]  저도 회식 못 갈 때 살짝 슬펐어요
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1199.12s -> 1201.83s]  또 재밌었다 해가지고
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1201.83s -> 1205.98s]  진짜 지효 님이 귀엽잖아요
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1205.98s -> 1210.71s]  아니 저 없어도 이제 어색한 사이들은 아니었잖아요
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1210.71s -> 1212.37s]  진짜 어색했을 거예요
#   신뢰도 - 무음: 0.32, 로그확률: -0.42
# [1216.37s -> 1218.19s]  상주님 이런데도 어색한데?
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1218.84s -> 1220.02s]  제가 자리를
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1220.82s -> 1222.36s]  여기가 상주님이면
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1222.36s -> 1224.38s]  이렇게 테이블이 있으면
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1224.38s -> 1226.18s]  여기 맨 끝에 앉아버릴거에요
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1226.98s -> 1228.62s]  여기 옆에 재형님 가면
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1230.25s -> 1231.43s]  이러고 있을거에요
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1234.04s -> 1235.18s]  재형님이 말이 없긴해요
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1235.18s -> 1236.70s]  재형님 그때 취했어요
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1236.70s -> 1239.02s]  아 네 들었어요 포장불렀다고
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1239.02s -> 1241.45s]  맞아요 저한테 군대가라고 하셨어요
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1241.45s -> 1246.27s]  아니 재형님이 말이 얼마나 안나면
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1246.59s -> 1248.09s]  우리 이거 해가지고
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1248.09s -> 1250.62s]  이거 인식시키는데
#   신뢰도 - 무음: 0.23, 로그확률: -0.26
# [1250.62s -> 1257.77s]  근데 재형님 말을 별로 안해서 군집 그게 안되서 인식이 안되는거에요
#   신뢰도 - 무음: 0.46, 로그확률: -0.27
# [1257.77s -> 1259.01s]  4명으로만 인식이 되는거에요
#   신뢰도 - 무음: 0.46, 로그확률: -0.27
# [1259.80s -> 1260.79s]  재형님이 없다고?
#   신뢰도 - 무음: 0.46, 로그확률: -0.27
# [1260.93s -> 1266.59s]  그래서 어제 저녁에 말을 많이 시켰더니 그제서야 인식하더라구요
#   신뢰도 - 무음: 0.46, 로그확률: -0.27
# [1266.82s -> 1273.91s]  매일 데이터를 녹음해요?
#   신뢰도 - 무음: 0.46, 로그확률: -0.27
# [1275.03s -> 1278.73s]  네 회의할때마다 다 녹음해요 지금 이렇게
#   신뢰도 - 무음: 0.46, 로그확률: -0.27
# [1280.48s -> 1284.41s]  근데 우리 회의실에서는 조용하니까 잘 나오는데
#   신뢰도 - 무음: 0.46, 로그확률: -0.27
# [1284.41s -> 1288.53s]  여기서 제가 하는게 소음이 좀 많으니까
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1297.59s -> 1299.21s]  무슨 음원프로그램이에요?
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1300.29s -> 1301.83s]  이거 네이버 클로바
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1302.07s -> 1305.71s]  그럼 얘는 자동으로 해주는거 아니에요?
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1306.67s -> 1308.15s]  아 자동으로 해주긴 하는데
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1308.15s -> 1310.73s]  이 음성파일이 필요한거니까 데이터 자체가
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1314.44s -> 1316.62s]  이거 그냥 클라우드에 올리고
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1316.62s -> 1318.30s]  그냥 그거에서 이제
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1318.30s -> 1321.06s]  STT 그런거 작업해서 해요
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1321.06s -> 1376.32s]  자꾸 이렇게 말했어요?
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1376.54s -> 1377.80s]  처음 먹어봐요
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1377.80s -> 1378.44s]  아 처음 먹어봐요?
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1378.50s -> 1379.28s]  나 일단 했어
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1379.28s -> 1383.55s]  원래 항상 저녁에 와서 식은거만 먹다가
#   신뢰도 - 무음: 0.17, 로그확률: -0.36
# [1384.27s -> 1386.87s]  점심에 와서 좀 뜨거운 거 먹으니까 더 맛있는 거 같기도 하고
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1386.87s -> 1457.47s]  근데 어르신들도 되게 많네요
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1492.80s -> 1494.30s]  거긴 발표 누가 해요 오늘?
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1496.23s -> 1496.79s]  원님?
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1497.15s -> 1497.71s]  원님
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1497.71s -> 1498.57s]  아 좋은데요
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1498.57s -> 1501.50s]  그런 거 이제 원님 시키면 되는 거 아니에요?
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1502.75s -> 1504.39s]  저희끼리 말할 때도 말을 안 하시는데
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1504.39s -> 1505.31s]  처리해주세요
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1519.81s -> 1520.27s]  네?
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1520.47s -> 1521.37s]  알아서 처리해주세요
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1522.03s -> 1522.85s]  처리 안 할 건데요
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1532.14s -> 1534.70s]  직장인분 언급하고 싶으면 이거 멈췄다 다시 시작하면 돼요
#   신뢰도 - 무음: 0.18, 로그확률: -0.36
# [1573.01s -> 1573.77s]  저도 배불러요
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1574.33s -> 1576.28s]  저도 배부르네
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1576.28s -> 1579.72s]  오늘 국밥질이 완전히 늦어졌어요
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1579.72s -> 1589.54s]  세 접시만에 벗겨버렸어요
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1589.54s -> 1599.82s]  세 접시만에 다 그어야지 의미는
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1604.58s -> 1606.40s]  하나씩 다 먹어봤습니다
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1606.70s -> 1608.00s]  그럼 된거죠
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1608.00s -> 1612.25s]  저 만두 찾다가 못 찾았는데
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1613.17s -> 1614.21s]  진짜요?
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1614.21s -> 1614.57s]  어?
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1614.99s -> 1615.55s]  가운데?
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1615.75s -> 1617.71s]  저 나무 상자
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1617.71s -> 1620.88s]  만두가 햄이 조금 열어지면
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1620.88s -> 1623.50s]  진짜 그냥 입걸음만 붙잖아
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1639.09s -> 1640.51s]  호랑이 못 입었어 진짜
#   신뢰도 - 무음: 0.05, 로그확률: -0.50
# [1640.51s -> 1643.25s]  아 여깄다 여깄네
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1643.25s -> 1655.48s]  마플 아이스크림
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1655.48s -> 1664.44s]  왜 그 디저트에 따로 오라는 거지?
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1664.60s -> 1666.91s]  저 이제 가지러 갈라고
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1667.35s -> 1668.61s]  마플 사주세요
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1671.39s -> 1673.23s]  디저트 사올게요
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1683.74s -> 1684.82s]  카페에서 마플 파니까
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1684.82s -> 1685.54s]  진짜요?
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1690.28s -> 1690.98s]  카페 할 바 있어요
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1690.98s -> 1691.54s]  감사합니다
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1692.22s -> 1697.88s]  저 오빠가 카페에 막 주말마다 돌려가서 일을 한다고
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1697.88s -> 1699.96s]  아까 안 맞..
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1699.96s -> 1700.72s]  아니 친하다고 하셨어요
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1700.72s -> 1702.26s]  아 네 맞습니다
#   신뢰도 - 무음: 0.23, 로그확률: -0.60
# [1702.26s -> 1760.61s]  저도 그게 제일 맛있는 것 같아요
#   신뢰도 - 무음: 0.19, 로그확률: -0.44
# [1802.66s -> 1805.76s]  와플 도우도 말차 들어갔어요
#   신뢰도 - 무음: 0.19, 로그확률: -0.44
# [1807.07s -> 1815.92s]  지금 말차 컨셉이잖아요
#   신뢰도 - 무음: 0.19, 로그확률: -0.44
# [1816.37s -> 1818.55s]  몰랐어요 방금 알았어요
#   신뢰도 - 무음: 0.19, 로그확률: -0.44
# [1824.24s -> 1826.52s]  전 알아가지고 여기 오자고 하시는 줄 알았어요
#   신뢰도 - 무음: 0.19, 로그확률: -0.44
# [1850.99s -> 1855.27s]  자기가 좋아하는 것만 많이 먹어요
#   신뢰도 - 무음: 0.19, 로그확률: -0.44
# [1880.66s -> 1882.14s]  내잡치는 무리였나
#   신뢰도 - 무음: 0.19, 로그확률: -0.44
# [1884.54s -> 1885.86s]  내잡치예요?
#   신뢰도 - 무음: 0.19, 로그확률: -0.44
# [1887.39s -> 1888.75s]  이런건 접시로 안쳐요
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1894.16s -> 1895.13s]  윤희 몇 접시에요?
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1903.05s -> 1904.47s]  서울동이 안길렀나요?
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1904.61s -> 1905.71s]  이렇게 싸우는거
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1922.28s -> 1923.88s]  나이 차이가 몇인데?
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1924.16s -> 1925.14s]  저요?
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1926.02s -> 1927.24s]  제가 모르겠는데요
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1927.24s -> 1929.55s]  오시는 곳에 이런거에요
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1930.09s -> 1931.03s]  애슐리를?
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1931.21s -> 1935.81s]  내주보험 들어왔으면 사드리는데도 돈이 안들어왔어요
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1942.00s -> 1943.52s]  내주보험 들어가면 한번더 하죠
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1943.52s -> 1946.80s]  나는 커피면 돼요
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1946.80s -> 1949.95s]  근데 언제 들어올지 몰라요
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1952.83s -> 1954.47s]  주말에 일하는거에요
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1954.47s -> 1955.61s]  명시되어있는게 아니에요?
#   신뢰도 - 무음: 0.11, 로그확률: -0.40
# [1955.61s -> 1956.53s]  주는 날짜가?
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [1967.01s -> 1968.29s]  질려서 안좋아해
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [1970.33s -> 1972.43s]  오빠가 밥돼서 막 그래줘요
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [1972.43s -> 1983.52s]  여기 와사비가 많다
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [1983.52s -> 1984.68s]  다?
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [1984.98s -> 2010.52s]  다 배부르다 왔어요
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2014.47s -> 2015.81s]  배를 채우는 음식이 아니야?
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2015.87s -> 2017.01s]  원래 간식배는 따로 해요
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2017.31s -> 2020.53s]  저는 배부르다 왔어요
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2020.85s -> 2022.31s]  많이 못 먹는다 그랬어요
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2022.31s -> 2025.52s]  근데 생각보다 많이 드셨네?
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2025.54s -> 2026.22s]  많이 드신 것 같은데
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2028.16s -> 2029.00s]  더 드세요
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2029.00s -> 2029.82s]  더 드세요
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2031.28s -> 2033.06s]  절대 눈치 주는 게 아니에요
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2034.06s -> 2034.76s]  미쳤어요 이거
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2034.76s -> 2035.66s]  뭔데요?
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2035.66s -> 2036.48s]  티라미수
#   신뢰도 - 무음: 0.14, 로그확률: -0.48
# [2036.48s -> 2054.94s]  이럴때 과일 먹어도 되지
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2054.94s -> 2057.39s]  말이 별로 없더라구요
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2057.39s -> 2058.15s]  별로 없어요?
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2058.31s -> 2073.42s]  진짜 맛있어
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2073.42s -> 2073.78s]  왜?
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2074.04s -> 2075.04s]  디저트
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2075.04s -> 2076.22s]  아 디저트
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2078.28s -> 2080.38s]  제가 디저트 앞까지 덮었는데요
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2080.38s -> 2080.70s]  네
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2080.70s -> 2081.92s]  맛있다
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2087.13s -> 2093.56s]  저는 치즈케이크가 맛있더라구요
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2093.56s -> 2095.00s]  저희 집앞에
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2095.00s -> 2096.32s]  맛있더라구요
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2099.39s -> 2101.13s]  녹차를 다들 좋아하시더라구요
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2101.13s -> 2101.83s]  네
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2105.21s -> 2106.71s]  녹차 맛있잖아요
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2106.71s -> 2107.25s]  네 녹차
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2107.25s -> 2120.85s]  초록색을 드시면 된다고요
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2120.85s -> 2120.91s]  네
#   신뢰도 - 무음: 0.10, 로그확률: -0.42
# [2124.59s -> 2127.43s]  바닐라 아이스크림 넣어 먹으면 아프고 맛있어
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2128.77s -> 2129.69s]  맛있겠다
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2143.74s -> 2145.62s]  저희 행복이 1순위 아닌가요?
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2147.55s -> 2148.19s]  그럼요
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2148.19s -> 2150.29s]  저는 행복을 포기했습니다
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2165.92s -> 2167.36s]  행복하게 살고 있어요
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2167.36s -> 2179.05s]  지금 달려오는 건 안 행복해 지금
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2179.05s -> 2183.84s]  이제 이거 먹으면 살 두룩두룩 찌릈지
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2183.84s -> 2184.88s]  그러게요
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2186.00s -> 2187.60s]  호랑이님 또 살 찌세요?
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2187.76s -> 2191.85s]  저는 사람 아니에요?
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2192.19s -> 2195.54s]  왜 저는 안 물어봐요
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2195.54s -> 2201.74s]  호랑이님 또 살 찌세요?
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2201.92s -> 2204.92s]  요새 찔 데가 없는데
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2205.60s -> 2206.30s]  진짜요
#   신뢰도 - 무음: 0.13, 로그확률: -0.41
# [2206.30s -> 2208.26s]  왜 이렇게 열받지?
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2215.73s -> 2217.51s]  관리를 해서 살이 다 빼진 거죠
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2219.59s -> 2220.81s]  아니 너무 말리셨길래
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2220.81s -> 2222.74s]  저거 드셔야 되는 거 아니에요?
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2223.42s -> 2224.28s]  아니 먹어요
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2230.45s -> 2231.47s]  문자 사신 적 있나요?
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2231.49s -> 2233.67s]  저는 지금은 부모님이랑이에요
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2237.27s -> 2238.81s]  저희도 자취할 때 노래 맞죠?
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2238.89s -> 2256.06s]  바비 같은 거 재세요?
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2256.90s -> 2257.76s]  우리는 못 재세요
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2258.40s -> 2258.76s]  그래요?
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2260.36s -> 2271.91s]  그리고 다 씨는 아니에요
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2271.91s -> 2272.77s]  씨 아니에요?
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2277.00s -> 2277.48s]  이렇게?
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2277.76s -> 2278.70s]  이런 느낌?
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2278.82s -> 2279.54s]  나오려다가
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2283.28s -> 2284.52s]  식성률 몇 퍼일 거 같은데
#   신뢰도 - 무음: 0.30, 로그확률: -0.53
# [2288.51s -> 2292.02s]  근데 이게 남자랑 여자랑 좀 다르다고
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2293.20s -> 2296.08s]  남자는 15%일까?
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2296.18s -> 2298.72s]  그게 평균인가요?
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2299.28s -> 2300.26s]  건강한 분
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2301.26s -> 2302.40s]  평균은 아니고
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2304.00s -> 2304.80s]  여성분들이어야지 이제
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2306.00s -> 2308.16s]  건강하다? 여자는? 20%?
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2308.94s -> 2311.84s]  여성분들은 남성분보다 좀 많이 높다고 해서
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2311.84s -> 2313.76s]  20 몇 퍼 아니에요?
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2314.78s -> 2316.59s]  저 몇 퍼일 것 같아요?
#   신뢰도 - 무음: 0.26, 로그확률: -0.36
# [2316.59s -> 2317.37s]  뭘까요?
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2321.61s -> 2322.41s]  팔씨끌어내
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2327.37s -> 2328.17s]  죄송합니다
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2335.21s -> 2337.13s]  아 나 다리를 얘기 안했잖아
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2350.05s -> 2350.53s]  아직
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2351.01s -> 2352.69s]  살 생활에서 반말을 못하네
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2366.77s -> 2367.87s]  주영이 운동하세요?
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2368.05s -> 2368.81s]  아니요
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2368.81s -> 2394.69s]  너무 놀래던데
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2394.69s -> 2396.53s]  아 근데 저는 여자들 기준을 몰라서
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2399.67s -> 2401.95s]  근데 그거 나 지금 녹음 됐는 줄 알아요?
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2403.22s -> 2404.62s]  이거 학습에 쓰이나요?
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2405.96s -> 2407.36s]  아니 학습 말고
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2408.81s -> 2411.07s]  그냥 우리 지금 모델 정하는 데 쓰고 있어요
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2411.07s -> 2413.59s]  학습에 쓰지는 말아주세요
#   신뢰도 - 무음: 0.10, 로그확률: -0.48
# [2414.53s -> 2416.51s]  왜요? 누구 뒷담화 들어갔어요 또?
#   신뢰도 - 무음: 0.17, 로그확률: -0.19
# [2416.67s -> 2419.17s]  이제 퍼스널 신체 정보가 들어갔습니다
#   신뢰도 - 무음: 0.17, 로그확률: -0.19
# [2421.25s -> 2422.79s]  기훈님 개인정보가 들어갔어요
#   신뢰도 - 무음: 0.17, 로그확률: -0.19
# [2424.97s -> 2426.31s]  마스킹 처리 해드릴게요
#   신뢰도 - 무음: 0.17, 로그확률: -0.19
# [2426.85s -> 2427.25s]  감사합니다
#   신뢰도 - 무음: 0.17, 로그확률: -0.19
# [2482.64s -> 2484.34s]  배불러요 하면서 계속 드시고 있는데
#   신뢰도 - 무음: 0.17, 로그확률: -0.19
# [2484.34s -> 2493.23s]  기훈님 배불러요? 배불러요?
#   신뢰도 - 무음: 0.17, 로그확률: -0.19
# [2510.53s -> 2512.41s]  40분 정도면 충분하겠죠?
#   신뢰도 - 무음: 0.11, 로그확률: -0.63
#
# 총 417개의 유효한 세그먼트

# %%
# 반복되는 텍스트 제거 (수정 버전)
def remove_repetitions(segments, max_repeat=3):
    """
    같은 텍스트가 연속으로 나오면 제거
    """
    filtered = []
    prev_texts = []

    for seg in segments:
        text = seg.text.strip()

        # 비어있는 텍스트 제거
        if not text or len(text) < 2:
            continue

        # "아 아 아..." 같은 패턴 감지
        words = text.split()
        if len(words) > 5 and len(set(words)) == 1:
            print(f"⚠️ 반복 단어 제거: [{seg.start:.2f}s] {text}")
            continue

        # 최근 텍스트와 비교
        if text not in prev_texts[-max_repeat:]:
            filtered.append(seg)
            prev_texts.append(text)
        else:
            print(f"⚠️ 중복 제거: [{seg.start:.2f}s] {text}")

    return filtered

# 필터링 적용
filtered_segments = remove_repetitions(valid_segments, max_repeat=2)

print(f"\n=== 최종 결과 (반복 제거 후) ===")
for seg in filtered_segments:
    print(f"[{seg.start:.2f}s -> {seg.end:.2f}s] {seg.text}")
# Out:
# ⚠️ 반복 단어 제거: [3.44s] 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아 아
# ⚠️ 중복 제거: [1056.89s] 진짜 중반까지 면치진거지
# ⚠️ 중복 제거: [1075.36s] 아니 허리를 안추고 다니셔
# ⚠️ 중복 제거: [2029.00s] 더 드세요
#
# === 최종 결과 (반복 제거 후) ===
# [30.85s -> 33.05s]  기훈님은 원래 어떻게 드시나요?
# [33.45s -> 35.27s]  저 예전에 오는 기억이 없더라고요
# [64.67s -> 80.24s]  아 못 들어가지 싶어요
# [80.94s -> 98.80s]  모일 때마다 나와요
# [98.80s -> 99.82s]  습해지네요
# [99.82s -> 100.58s]  너무 맛있어요
# [101.46s -> 102.34s]  어떤 시간에 먹어요?
# [102.38s -> 104.02s]  딸기 많이 먹어야 된다는 생각이 들어요
# [104.02s -> 105.28s]  1시간이면 충분하지 않아요?
# [105.48s -> 110.13s]  저는 항상 술 꽉 채우고 나와요
# [110.87s -> 113.99s]  1시간 50분까지 먹을 건데요?
# [116.38s -> 117.36s]  저희 몇 시까지 먹는 거예요?
# [117.44s -> 118.44s]  1시간 50분까지요
# [118.88s -> 120.56s]  근데 진짜 그렇게 먹을 수 있어요?
# [120.82s -> 121.18s]  아니요
# [121.18s -> 137.05s]  지금 녹음하고 있는 거예요?
# [138.89s -> 146.53s]  안 될 것 같은데 마이크로 찍었잖아요
# [147.68s -> 149.28s]  모양이 명확하게 있어가지고
# [151.44s -> 157.64s]  이거 눌러먹는 거 아니에요?
# [158.76s -> 175.20s]  진짜 행복해
# [175.20s -> 176.88s]  얼굴이 행복해 보여요
# [176.88s -> 180.19s]  진짜 많이 하거든요
# [226.98s -> 229.32s]  생각보다 자리가 금방 나서 다행인 것 같아요
# [229.32s -> 240.05s]  생각보다 사람이 많대요
# [240.87s -> 241.37s]  평일인데
# [241.37s -> 244.92s]  우리 같은 사람들이 많지 않을까요?
# [244.96s -> 245.90s]  그냥 밥 먹으러
# [245.90s -> 296.50s]  그러니 야채는 드시네요
# [296.50s -> 297.38s]  편의점 많지
# [297.38s -> 300.06s]  입 잘 따고 하시길래 야채도 안 먹었어요 진짜로
# [300.06s -> 302.40s]  야채는 먹어요 원래 안 먹었는데
# [304.24s -> 304.92s]  먹어야겠더라구요
# [304.92s -> 310.20s]  저도 그러고 있어요
# [310.20s -> 311.78s]  야채하고 과일
# [311.78s -> 314.10s]  근데 과일은 원래 항상 좋아
# [317.08s -> 319.00s]  근데 혼자 살면 잘 안 먹게 되지 않아요?
# [320.27s -> 321.95s]  동가가 진짜 엄청 많고
# [321.95s -> 333.32s]  고댄찌개집 갔으면 저 슬플 뻔 했잖아요 성현님
# [333.32s -> 336.40s]  고댄찌개집 갔으면 저 슬플 뻔 했잖아요
# [338.50s -> 339.90s]  고댄찌개 가다고 했나요 제가?
# [340.28s -> 340.96s]  처음에
# [340.96s -> 353.70s]  아니 지금 얼굴에 웃음이 끊이지가 않으세요
# [377.42s -> 378.26s]  본가가 못 가요?
# [378.78s -> 385.14s]  뭘 못 가요?
# [385.22s -> 385.94s]  본가요
# [386.81s -> 387.71s]  왜 못 가요?
# [388.46s -> 389.18s]  멀어서
# [389.78s -> 393.94s]  갈 때마다 본가 갈 때 가요
# [395.76s -> 397.56s]  본가 갈 때마다 먹어야죠
# [397.56s -> 399.26s]  지금 좋은데 먹어요
# [399.26s -> 401.92s]  과일은 원래 더 안 먹어요
# [402.52s -> 405.42s]  본가 가면 거의 집에 과일이 많아서
# [405.42s -> 408.44s]  1년에 한두 번 밖에 안 가요
# [409.69s -> 410.23s]  왜요?
# [410.51s -> 412.89s]  저도 한두 번 밖에 안 가서 할만해요
# [412.89s -> 417.57s]  거리가 머시니까 조금더
# [419.36s -> 420.40s]  얼마있죠?
# [420.56s -> 421.28s]  마치 차타요
# [423.24s -> 424.38s]  근데 차타가 어디에요?
# [427.35s -> 428.97s]  차타가 30분이어서
# [428.97s -> 430.29s]  아 그럼 자주 와야겠다
# [430.90s -> 434.50s]  귀찮은데 안오면 껍껍해하셔서 가요
# [441.13s -> 442.71s]  전화 자주하면 그만하래요
# [443.21s -> 444.57s]  얼마나 자주 하세요 지금?
# [444.75s -> 447.55s]  2-3일 한 번씩 했더니 자주 아니면 그만하래
# [447.79s -> 448.89s]  할 말 없겠네
# [453.12s -> 454.38s]  그냥 안부전화가
# [454.78s -> 461.04s]  밥 먹었나? 밥 먹었대요
# [463.41s -> 465.79s]  오늘 뭐했는데? 오늘 뭐 회사 갔다왔지 끝
# [467.78s -> 468.98s]  밥 뭐 먹었는데?
# [468.98s -> 473.54s]  나 집에 있는거 먹어봤다
# [473.54s -> 475.48s]  집에 있는거 뭐 먹었냐?
# [481.84s -> 483.42s]  엄마랑 딸이 치전데
# [485.26s -> 486.86s]  원래 반대로 물어보는게 맞지?
# [488.03s -> 490.49s]  바뀌었어요 엄마 바뀌어서
# [490.49s -> 492.11s]  집에 일찍 가라 해서
# [492.11s -> 496.88s]  사람이 외동이라고 하시네
# [496.88s -> 497.88s]  아니요 오빠 하나 있어요
# [498.90s -> 500.66s]  봐주실래요?
# [501.91s -> 503.53s]  오빠는 못봐 보네
# [503.53s -> 504.91s]  오빠랑 사이 안좋아요
# [504.91s -> 506.51s]  아니요 안좋은데 좋아요
# [506.51s -> 508.45s]  뭔지 알아요?
# [510.66s -> 516.08s]  냄새가 안나요
# [516.08s -> 523.17s]  실수 따까리
# [523.17s -> 524.27s]  형 있어요?
# [524.65s -> 527.11s]  저도 동네인데 저는 성격이 더러워서
# [527.97s -> 529.96s]  뭘 시키면 싸웠어요
# [529.96s -> 538.32s]  너도 오빠 있어요?
# [539.78s -> 540.40s]  따까리에요?
# [540.80s -> 541.86s]  아니요 오빠랑 안 친해요
# [544.28s -> 545.34s]  아 짱 맛있어
# [545.34s -> 551.78s]  그냥 명절이나 이벤트 때 보는 사람 아니에요?
# [552.02s -> 552.44s]  맞아요
# [552.44s -> 559.26s]  근데 사실 형도 주식하고 저도 그러고 있으니까
# [559.64s -> 560.74s]  거의 안 만나시던데요
# [570.00s -> 570.70s]  1년에 한 번?
# [570.96s -> 573.14s]  두 번? 그렇게 안 만나요
# [573.68s -> 574.96s]  근데 형 일본이 있어요
# [574.96s -> 592.00s]  일본은 그냥 음식이 다 맛있던데요 저는
# [592.00s -> 593.22s]  저도 좀 그런거 같아요
# [600.71s -> 602.17s]  근데 저희 형도 입이 좀 까다로워서
# [602.17s -> 605.05s]  저는 진짜 아무거나 준비를 못하거든요
# [605.05s -> 607.63s]  근데 형이 좀 까다로워가지고
# [608.03s -> 610.33s]  알아서 맛집 차려놓고 직접 끌고 다닙니다
# [610.33s -> 613.90s]  여러분 김말이 매워요?
# [614.68s -> 615.54s]  그렇게 안 매워
# [616.36s -> 617.16s]  질려가지고
# [618.10s -> 621.30s]  뭐 드세요?
# [621.80s -> 623.10s]  매운 걸 잘 못 먹어요
# [624.27s -> 624.73s]  음...
# [625.55s -> 626.65s]  인생 절반쯤 해보자
# [632.64s -> 635.04s]  4세트 김치 진짜 맛있어
# [635.04s -> 636.78s]  진짜 진짜 짱 맛있어
# [636.78s -> 637.48s]  뭐가 맛있다고요?
# [637.48s -> 650.08s]  완전 상쾌해
# [650.08s -> 665.46s]  아침에 도랑매 안 드시길래 밥 끓인 줄 알았어요
# [665.46s -> 666.22s]  저도
# [666.64s -> 668.74s]  밥 끓인 줄 알았어요
# [677.80s -> 679.44s]  약속이 취소되는지 알았나봐요
# [679.44s -> 683.85s]  오후에 다 갔다 와야 돼가지고
# [685.13s -> 687.43s]  도랑님 늦으신 거 한 번도 못 본 거 같은데
# [687.43s -> 690.23s]  예전에 늦게 왔어요
# [690.23s -> 691.72s]  아 그래요?
# [695.68s -> 697.86s]  나왔는데 집에 투명점을 주고 온 거
# [723.24s -> 724.28s]  저한테 치는 거죠
# [751.88s -> 754.04s]  전 집에 있는 것도 좋아해요
# [754.04s -> 755.06s]  네 감사하세요
# [756.89s -> 757.53s]  대게요?
# [757.87s -> 758.93s]  아 해외요?
# [758.93s -> 762.18s]  다 말을 못 알아듣지. 내가 말하면 된다.
# [766.30s -> 775.94s]  운이 없어 봐.
# [776.94s -> 782.27s]  저도 형이 계속 일본 오라고 하는데 운이 없어 봐.
# [790.33s -> 790.97s]  맞아요.
# [792.57s -> 795.11s]  비행기를 좀 무서워해서.
# [796.82s -> 797.90s]  비행기 무서워요.
# [799.00s -> 799.92s]  그럼 해외항 가보세요.
# [800.32s -> 807.76s]  비행기 타고 갔는데 비행기 탈 때 청시만 먹었어요.
# [808.08s -> 821.56s]  비행기 타가지고 일단 서울 왔다 갔다 보니까 비행기가 더 싸요.
# [828.65s -> 830.51s]  진짜 국내에서는 한 번도 안 타봤는데.
# [831.15s -> 832.75s]  동네에서 만드셨나요?
# [833.91s -> 834.95s]  네, 만드셨어요
# [834.95s -> 837.59s]  근데 저는 지금 공항 앞이어서
# [837.59s -> 873.50s]  위에서 많이 못 먹어서 너무 슬퍼요
# [873.50s -> 875.00s]  안 먹으면 되죠
# [886.90s -> 887.32s]  배불러서요?
# [887.82s -> 892.74s]  약간 병원 가야겠다
# [892.74s -> 905.73s]  오전에 최대한 많이 하지 못했는데
# [905.73s -> 925.58s]  형님 말을 어렵게 하셔서
# [925.58s -> 927.52s]  많이 배우셔가지고
# [927.52s -> 928.42s]  형님이 말을
# [938.56s -> 940.92s]  짓다 마저도 제가 처리해 드릴게요
# [940.92s -> 941.28s]  아 그래요?
# [942.64s -> 945.22s]  욕하기 아니라 그냥
# [945.22s -> 946.68s]  내 스타일이 다르다
# [946.96s -> 953.49s]  진짜 굴러 먹는 것 같은데 어떡하죠?
# [954.17s -> 955.21s]  이게 욕이지
# [955.45s -> 961.50s]  전 사장님이 이게 좀 웃겨
# [963.45s -> 964.33s]  짜증나
# [964.33s -> 971.18s]  근데 확실히 좀 말이 어렵게 해준다고 교수님들 보면
# [971.18s -> 978.64s]  그리고 일할 때도 보면은 자꾸 그냥 자기가 뜯은 언어들
# [978.90s -> 980.02s]  용어 그런 거 쓰고
# [987.64s -> 989.82s]  맥앤치즈가 진짜 맛있는데
# [990.02s -> 991.58s]  그래서 이번에 가져왔어요
# [992.20s -> 992.72s]  바질튀김도
# [992.72s -> 1000.38s]  제가 많이 못 먹어요
# [1000.48s -> 1003.83s]  너무 슬퍼요
# [1006.59s -> 1008.25s]  나도 먹는 게 좀 줄어가지고
# [1008.25s -> 1009.33s]  저희는 이렇게 땡겨요
# [1009.33s -> 1010.88s]  이렇게 땋아서
# [1011.44s -> 1013.72s]  저희는 많이 먹어야 돼요
# [1013.72s -> 1014.40s]  성장기라서
# [1014.40s -> 1022.68s]  여기서 더 커지면 징그러울 것 같은데 이제
# [1030.34s -> 1031.56s]  어? 더 커보이는데?
# [1032.56s -> 1033.64s]  반울림해서 좀
# [1033.64s -> 1037.20s]  그냥 반울림하고 말하고 다녔는데
# [1037.52s -> 1040.04s]  아 이거 덩치가 있어서 그런가
# [1040.04s -> 1041.18s]  더 커보이긴 하는데
# [1042.48s -> 1047.31s]  저도 반울림하면 160이에요
# [1050.23s -> 1051.37s]  이때 더 커져요
# [1051.37s -> 1051.85s]  어디가 더 커?
# [1051.85s -> 1054.45s]  아니 센치 끝났어
# [1054.45s -> 1056.01s]  진짜 중반까지 면치진거지
# [1056.01s -> 1056.77s]  응?
# [1058.29s -> 1062.56s]  진짜 성장기라니까요
# [1062.56s -> 1067.56s]  나 신고때 33인가 그랬는데
# [1068.24s -> 1069.84s]  전역할때 입학할때 그거
# [1069.84s -> 1075.36s]  아니 허리를 안추고 다니셔
# [1079.56s -> 1079.98s]  힘들어
# [1079.98s -> 1081.54s]  그럼 겨누리세요
# [1110.72s -> 1112.35s]  그거 먹어도 더 먹을 수 있어요?
# [1112.51s -> 1114.51s]  이거 먹어도 더 먹을 수 있어요?
# [1114.69s -> 1125.83s]  뭔가 더 먹을 수 있을거 같다고 물어본거에요
# [1129.41s -> 1131.01s]  저녁에도 회식이 있잖아요
# [1131.01s -> 1136.58s]  근데 거기서는 좀 술 마시는 거 아니에요?
# [1138.54s -> 1140.32s]  술을 좋아할 수 있는 분들이 없어서
# [1140.32s -> 1148.16s]  대사에 도출받아 봐
# [1148.16s -> 1162.72s]  개인 역량이긴 한데
# [1172.14s -> 1172.84s]  정해볼까 봐
# [1172.84s -> 1174.72s]  한 병까진 괜찮습니다
# [1186.88s -> 1188.22s]  저도 한 병 반?
# [1192.32s -> 1193.96s]  술 먹는 걸 좋아해가지고
# [1196.82s -> 1199.12s]  저도 회식 못 갈 때 살짝 슬펐어요
# [1199.12s -> 1201.83s]  또 재밌었다 해가지고
# [1201.83s -> 1205.98s]  진짜 지효 님이 귀엽잖아요
# [1205.98s -> 1210.71s]  아니 저 없어도 이제 어색한 사이들은 아니었잖아요
# [1210.71s -> 1212.37s]  진짜 어색했을 거예요
# [1216.37s -> 1218.19s]  상주님 이런데도 어색한데?
# [1218.84s -> 1220.02s]  제가 자리를
# [1220.82s -> 1222.36s]  여기가 상주님이면
# [1222.36s -> 1224.38s]  이렇게 테이블이 있으면
# [1224.38s -> 1226.18s]  여기 맨 끝에 앉아버릴거에요
# [1226.98s -> 1228.62s]  여기 옆에 재형님 가면
# [1230.25s -> 1231.43s]  이러고 있을거에요
# [1234.04s -> 1235.18s]  재형님이 말이 없긴해요
# [1235.18s -> 1236.70s]  재형님 그때 취했어요
# [1236.70s -> 1239.02s]  아 네 들었어요 포장불렀다고
# [1239.02s -> 1241.45s]  맞아요 저한테 군대가라고 하셨어요
# [1241.45s -> 1246.27s]  아니 재형님이 말이 얼마나 안나면
# [1246.59s -> 1248.09s]  우리 이거 해가지고
# [1248.09s -> 1250.62s]  이거 인식시키는데
# [1250.62s -> 1257.77s]  근데 재형님 말을 별로 안해서 군집 그게 안되서 인식이 안되는거에요
# [1257.77s -> 1259.01s]  4명으로만 인식이 되는거에요
# [1259.80s -> 1260.79s]  재형님이 없다고?
# [1260.93s -> 1266.59s]  그래서 어제 저녁에 말을 많이 시켰더니 그제서야 인식하더라구요
# [1266.82s -> 1273.91s]  매일 데이터를 녹음해요?
# [1275.03s -> 1278.73s]  네 회의할때마다 다 녹음해요 지금 이렇게
# [1280.48s -> 1284.41s]  근데 우리 회의실에서는 조용하니까 잘 나오는데
# [1284.41s -> 1288.53s]  여기서 제가 하는게 소음이 좀 많으니까
# [1297.59s -> 1299.21s]  무슨 음원프로그램이에요?
# [1300.29s -> 1301.83s]  이거 네이버 클로바
# [1302.07s -> 1305.71s]  그럼 얘는 자동으로 해주는거 아니에요?
# [1306.67s -> 1308.15s]  아 자동으로 해주긴 하는데
# [1308.15s -> 1310.73s]  이 음성파일이 필요한거니까 데이터 자체가
# [1314.44s -> 1316.62s]  이거 그냥 클라우드에 올리고
# [1316.62s -> 1318.30s]  그냥 그거에서 이제
# [1318.30s -> 1321.06s]  STT 그런거 작업해서 해요
# [1321.06s -> 1376.32s]  자꾸 이렇게 말했어요?
# [1376.54s -> 1377.80s]  처음 먹어봐요
# [1377.80s -> 1378.44s]  아 처음 먹어봐요?
# [1378.50s -> 1379.28s]  나 일단 했어
# [1379.28s -> 1383.55s]  원래 항상 저녁에 와서 식은거만 먹다가
# [1384.27s -> 1386.87s]  점심에 와서 좀 뜨거운 거 먹으니까 더 맛있는 거 같기도 하고
# [1386.87s -> 1457.47s]  근데 어르신들도 되게 많네요
# [1492.80s -> 1494.30s]  거긴 발표 누가 해요 오늘?
# [1496.23s -> 1496.79s]  원님?
# [1497.15s -> 1497.71s]  원님
# [1497.71s -> 1498.57s]  아 좋은데요
# [1498.57s -> 1501.50s]  그런 거 이제 원님 시키면 되는 거 아니에요?
# [1502.75s -> 1504.39s]  저희끼리 말할 때도 말을 안 하시는데
# [1504.39s -> 1505.31s]  처리해주세요
# [1519.81s -> 1520.27s]  네?
# [1520.47s -> 1521.37s]  알아서 처리해주세요
# [1522.03s -> 1522.85s]  처리 안 할 건데요
# [1532.14s -> 1534.70s]  직장인분 언급하고 싶으면 이거 멈췄다 다시 시작하면 돼요
# [1573.01s -> 1573.77s]  저도 배불러요
# [1574.33s -> 1576.28s]  저도 배부르네
# [1576.28s -> 1579.72s]  오늘 국밥질이 완전히 늦어졌어요
# [1579.72s -> 1589.54s]  세 접시만에 벗겨버렸어요
# [1589.54s -> 1599.82s]  세 접시만에 다 그어야지 의미는
# [1604.58s -> 1606.40s]  하나씩 다 먹어봤습니다
# [1606.70s -> 1608.00s]  그럼 된거죠
# [1608.00s -> 1612.25s]  저 만두 찾다가 못 찾았는데
# [1613.17s -> 1614.21s]  진짜요?
# [1614.21s -> 1614.57s]  어?
# [1614.99s -> 1615.55s]  가운데?
# [1615.75s -> 1617.71s]  저 나무 상자
# [1617.71s -> 1620.88s]  만두가 햄이 조금 열어지면
# [1620.88s -> 1623.50s]  진짜 그냥 입걸음만 붙잖아
# [1639.09s -> 1640.51s]  호랑이 못 입었어 진짜
# [1640.51s -> 1643.25s]  아 여깄다 여깄네
# [1643.25s -> 1655.48s]  마플 아이스크림
# [1655.48s -> 1664.44s]  왜 그 디저트에 따로 오라는 거지?
# [1664.60s -> 1666.91s]  저 이제 가지러 갈라고
# [1667.35s -> 1668.61s]  마플 사주세요
# [1671.39s -> 1673.23s]  디저트 사올게요
# [1683.74s -> 1684.82s]  카페에서 마플 파니까
# [1684.82s -> 1685.54s]  진짜요?
# [1690.28s -> 1690.98s]  카페 할 바 있어요
# [1690.98s -> 1691.54s]  감사합니다
# [1692.22s -> 1697.88s]  저 오빠가 카페에 막 주말마다 돌려가서 일을 한다고
# [1697.88s -> 1699.96s]  아까 안 맞..
# [1699.96s -> 1700.72s]  아니 친하다고 하셨어요
# [1700.72s -> 1702.26s]  아 네 맞습니다
# [1702.26s -> 1760.61s]  저도 그게 제일 맛있는 것 같아요
# [1802.66s -> 1805.76s]  와플 도우도 말차 들어갔어요
# [1807.07s -> 1815.92s]  지금 말차 컨셉이잖아요
# [1816.37s -> 1818.55s]  몰랐어요 방금 알았어요
# [1824.24s -> 1826.52s]  전 알아가지고 여기 오자고 하시는 줄 알았어요
# [1850.99s -> 1855.27s]  자기가 좋아하는 것만 많이 먹어요
# [1880.66s -> 1882.14s]  내잡치는 무리였나
# [1884.54s -> 1885.86s]  내잡치예요?
# [1887.39s -> 1888.75s]  이런건 접시로 안쳐요
# [1894.16s -> 1895.13s]  윤희 몇 접시에요?
# [1903.05s -> 1904.47s]  서울동이 안길렀나요?
# [1904.61s -> 1905.71s]  이렇게 싸우는거
# [1922.28s -> 1923.88s]  나이 차이가 몇인데?
# [1924.16s -> 1925.14s]  저요?
# [1926.02s -> 1927.24s]  제가 모르겠는데요
# [1927.24s -> 1929.55s]  오시는 곳에 이런거에요
# [1930.09s -> 1931.03s]  애슐리를?
# [1931.21s -> 1935.81s]  내주보험 들어왔으면 사드리는데도 돈이 안들어왔어요
# [1942.00s -> 1943.52s]  내주보험 들어가면 한번더 하죠
# [1943.52s -> 1946.80s]  나는 커피면 돼요
# [1946.80s -> 1949.95s]  근데 언제 들어올지 몰라요
# [1952.83s -> 1954.47s]  주말에 일하는거에요
# [1954.47s -> 1955.61s]  명시되어있는게 아니에요?
# [1955.61s -> 1956.53s]  주는 날짜가?
# [1967.01s -> 1968.29s]  질려서 안좋아해
# [1970.33s -> 1972.43s]  오빠가 밥돼서 막 그래줘요
# [1972.43s -> 1983.52s]  여기 와사비가 많다
# [1983.52s -> 1984.68s]  다?
# [1984.98s -> 2010.52s]  다 배부르다 왔어요
# [2014.47s -> 2015.81s]  배를 채우는 음식이 아니야?
# [2015.87s -> 2017.01s]  원래 간식배는 따로 해요
# [2017.31s -> 2020.53s]  저는 배부르다 왔어요
# [2020.85s -> 2022.31s]  많이 못 먹는다 그랬어요
# [2022.31s -> 2025.52s]  근데 생각보다 많이 드셨네?
# [2025.54s -> 2026.22s]  많이 드신 것 같은데
# [2028.16s -> 2029.00s]  더 드세요
# [2031.28s -> 2033.06s]  절대 눈치 주는 게 아니에요
# [2034.06s -> 2034.76s]  미쳤어요 이거
# [2034.76s -> 2035.66s]  뭔데요?
# [2035.66s -> 2036.48s]  티라미수
# [2036.48s -> 2054.94s]  이럴때 과일 먹어도 되지
# [2054.94s -> 2057.39s]  말이 별로 없더라구요
# [2057.39s -> 2058.15s]  별로 없어요?
# [2058.31s -> 2073.42s]  진짜 맛있어
# [2073.42s -> 2073.78s]  왜?
# [2074.04s -> 2075.04s]  디저트
# [2075.04s -> 2076.22s]  아 디저트
# [2078.28s -> 2080.38s]  제가 디저트 앞까지 덮었는데요
# [2080.70s -> 2081.92s]  맛있다
# [2087.13s -> 2093.56s]  저는 치즈케이크가 맛있더라구요
# [2093.56s -> 2095.00s]  저희 집앞에
# [2095.00s -> 2096.32s]  맛있더라구요
# [2099.39s -> 2101.13s]  녹차를 다들 좋아하시더라구요
# [2105.21s -> 2106.71s]  녹차 맛있잖아요
# [2106.71s -> 2107.25s]  네 녹차
# [2107.25s -> 2120.85s]  초록색을 드시면 된다고요
# [2124.59s -> 2127.43s]  바닐라 아이스크림 넣어 먹으면 아프고 맛있어
# [2128.77s -> 2129.69s]  맛있겠다
# [2143.74s -> 2145.62s]  저희 행복이 1순위 아닌가요?
# [2147.55s -> 2148.19s]  그럼요
# [2148.19s -> 2150.29s]  저는 행복을 포기했습니다
# [2165.92s -> 2167.36s]  행복하게 살고 있어요
# [2167.36s -> 2179.05s]  지금 달려오는 건 안 행복해 지금
# [2179.05s -> 2183.84s]  이제 이거 먹으면 살 두룩두룩 찌릈지
# [2183.84s -> 2184.88s]  그러게요
# [2186.00s -> 2187.60s]  호랑이님 또 살 찌세요?
# [2187.76s -> 2191.85s]  저는 사람 아니에요?
# [2192.19s -> 2195.54s]  왜 저는 안 물어봐요
# [2195.54s -> 2201.74s]  호랑이님 또 살 찌세요?
# [2201.92s -> 2204.92s]  요새 찔 데가 없는데
# [2205.60s -> 2206.30s]  진짜요
# [2206.30s -> 2208.26s]  왜 이렇게 열받지?
# [2215.73s -> 2217.51s]  관리를 해서 살이 다 빼진 거죠
# [2219.59s -> 2220.81s]  아니 너무 말리셨길래
# [2220.81s -> 2222.74s]  저거 드셔야 되는 거 아니에요?
# [2223.42s -> 2224.28s]  아니 먹어요
# [2230.45s -> 2231.47s]  문자 사신 적 있나요?
# [2231.49s -> 2233.67s]  저는 지금은 부모님이랑이에요
# [2237.27s -> 2238.81s]  저희도 자취할 때 노래 맞죠?
# [2238.89s -> 2256.06s]  바비 같은 거 재세요?
# [2256.90s -> 2257.76s]  우리는 못 재세요
# [2258.40s -> 2258.76s]  그래요?
# [2260.36s -> 2271.91s]  그리고 다 씨는 아니에요
# [2271.91s -> 2272.77s]  씨 아니에요?
# [2277.00s -> 2277.48s]  이렇게?
# [2277.76s -> 2278.70s]  이런 느낌?
# [2278.82s -> 2279.54s]  나오려다가
# [2283.28s -> 2284.52s]  식성률 몇 퍼일 거 같은데
# [2288.51s -> 2292.02s]  근데 이게 남자랑 여자랑 좀 다르다고
# [2293.20s -> 2296.08s]  남자는 15%일까?
# [2296.18s -> 2298.72s]  그게 평균인가요?
# [2299.28s -> 2300.26s]  건강한 분
# [2301.26s -> 2302.40s]  평균은 아니고
# [2304.00s -> 2304.80s]  여성분들이어야지 이제
# [2306.00s -> 2308.16s]  건강하다? 여자는? 20%?
# [2308.94s -> 2311.84s]  여성분들은 남성분보다 좀 많이 높다고 해서
# [2311.84s -> 2313.76s]  20 몇 퍼 아니에요?
# [2314.78s -> 2316.59s]  저 몇 퍼일 것 같아요?
# [2316.59s -> 2317.37s]  뭘까요?
# [2321.61s -> 2322.41s]  팔씨끌어내
# [2327.37s -> 2328.17s]  죄송합니다
# [2335.21s -> 2337.13s]  아 나 다리를 얘기 안했잖아
# [2350.05s -> 2350.53s]  아직
# [2351.01s -> 2352.69s]  살 생활에서 반말을 못하네
# [2366.77s -> 2367.87s]  주영이 운동하세요?
# [2368.05s -> 2368.81s]  아니요
# [2368.81s -> 2394.69s]  너무 놀래던데
# [2394.69s -> 2396.53s]  아 근데 저는 여자들 기준을 몰라서
# [2399.67s -> 2401.95s]  근데 그거 나 지금 녹음 됐는 줄 알아요?
# [2403.22s -> 2404.62s]  이거 학습에 쓰이나요?
# [2405.96s -> 2407.36s]  아니 학습 말고
# [2408.81s -> 2411.07s]  그냥 우리 지금 모델 정하는 데 쓰고 있어요
# [2411.07s -> 2413.59s]  학습에 쓰지는 말아주세요
# [2414.53s -> 2416.51s]  왜요? 누구 뒷담화 들어갔어요 또?
# [2416.67s -> 2419.17s]  이제 퍼스널 신체 정보가 들어갔습니다
# [2421.25s -> 2422.79s]  기훈님 개인정보가 들어갔어요
# [2424.97s -> 2426.31s]  마스킹 처리 해드릴게요
# [2426.85s -> 2427.25s]  감사합니다
# [2482.64s -> 2484.34s]  배불러요 하면서 계속 드시고 있는데
# [2484.34s -> 2493.23s]  기훈님 배불러요? 배불러요?
# [2510.53s -> 2512.41s]  40분 정도면 충분하겠죠?

# %%
# !pip install transformers sentencepiece

# %%
from transformers import pipeline
import torch
import time

## 1. 모델 로드 (GPU 사용)
# j5ng/et5-typos-corrector 모델을 불러옵니다.
# (참고: 처음 실행 시 모델 파일을 다운로드하며 몇 분 정도 소요될 수 있습니다.)
try:
    device = 0 if torch.cuda.is_available() else -1
    corrector = pipeline(
        "text2text-generation",
        model="j5ng/et5-typos-corrector",
        device=device
    )
    print("AI 교정 모델 로드 완료. (GPU 사용)" if device == 0 else "AI 교정 모델 로드 완료. (CPU 사용)")

except Exception as e:
    print(f"모델 로드 중 오류 발생: {e}")
    print("-> GPU 메모리가 부족할 수 있습니다. Colab 런타임을 '다시 시작'하고 이 셀부터 다시 실행해 보세요.")


## 2. 테스트 실행 (샘플 5개만)
# 'filtered_segments' 변수는 9번 셀에서 이미 생성되어 있어야 합니다.
if 'filtered_segments' in locals() and 'corrector' in locals():
    print("\n=== 맞춤법/띄어쓰기 교정 테스트 (매개변수 조절) ===")

    sample_segments = filtered_segments
    start_time = time.time()

    for seg in sample_segments:
        original_text = seg.text.strip()
        if not original_text: continue

        # [수정] 생성 옵션을 추가하여 창의성(무작위성)을 최소화
        corrected_text = corrector(
            original_text,
            max_length=256,
            do_sample=False,  # 샘플링 대신 가장 확률 높은 단어만 선택
            temperature=0.1   # 확률 분포를 더 뾰족하게 만들어 정해진 답 유도
        )[0]['generated_text']

        print(f"원본  : {original_text}")
        print(f"교정본: {corrected_text}")
        print("-" * 20)

    print(f"\n5개 샘플 처리 완료 (소요 시간: {time.time() - start_time:.2f}초)")

else:
    print("오류: 'filtered_segments' 변수 또는 'corrector' 모델을 찾을 수 없습니다.")
    print("-> 9번 셀이 정상적으로 실행되었는지, 모델 로드가 성공했는지 확인하세요.")
# Out:
# Device set to use cuda:0
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# AI 교정 모델 로드 완료. (GPU 사용)
#
# === 맞춤법/띄어쓰기 교정 테스트 (매개변수 조절) ===
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 기훈님은 원래 어떻게 드시나요?
# 교정본: 기훈 님은 원래 어떻게 드시나요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저 예전에 오는 기억이 없더라고요
# 교정본: 저 예전에 오는 기억이 없더라고요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아 못 들어가지 싶어요
# 교정본: 아 못 들어가지 싶어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 모일 때마다 나와요
# 교정본: 모일 때마다 나와요.
# --------------------
# 원본  : 습해지네요
# 교정본: 습해지네요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 너무 맛있어요
# 교정본: 너무 맛있어요 너무 맛있어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 어떤 시간에 먹어요?
# 교정본: 어떤 시간에 먹어요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 딸기 많이 먹어야 된다는 생각이 들어요
# 교정본: 딸기 많이 먹어야 된다는 생각이 들어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 1시간이면 충분하지 않아요?
# 교정본: ? 1시간이면 충분하지 않아요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저는 항상 술 꽉 채우고 나와요
# 교정본: 저는 항상 술 꽉 채우고 나와요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 1시간 50분까지 먹을 건데요?
# 교정본: 요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저희 몇 시까지 먹는 거예요?
# 교정본: 님은 저희 몇 시까지 먹는 거예요?.
# --------------------
# 원본  : 1시간 50분까지요
# 교정본: 1시간 50분까지요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 진짜 그렇게 먹을 수 있어요?
# 교정본: 님은 진짜 그렇게 먹을 수 있어요?.
# --------------------
# 원본  : 아니요
# 교정본: 아니요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 지금 녹음하고 있는 거예요?
# 교정본: 지금 녹음하고 있는 거예요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 안 될 것 같은데 마이크로 찍었잖아요
# 교정본: 안 될 것 같은데 마이크로 찍었잖아요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 모양이 명확하게 있어가지고
# 교정본: " 모양이 분명히 있어가지고" 있어 가지고.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 이거 눌러먹는 거 아니에요?
# 교정본: 님은 이거 눌러 먹는 거 아니에요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 진짜 행복해
# 교정본: hate-speech 진짜 행복해.
# --------------------
# 원본  : 얼굴이 행복해 보여요
# 교정본: 얼굴이 행복해 보여요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 진짜 많이 하거든요
# 교정본: 진짜 많이 하거든요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 생각보다 자리가 금방 나서 다행인 것 같아요
# 교정본: 생각보다 자리가 금방 나서 다행인 것 같아요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 생각보다 사람이 많대요
# 교정본: 생각보다 사람이 많대요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 평일인데
# 교정본: 님은 평일인데 평일인데.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 우리 같은 사람들이 많지 않을까요?
# 교정본: 우리 같은 사람들이 많지 않을까요?.
# --------------------
# 원본  : 그냥 밥 먹으러
# 교정본: 그냥 밥 먹으러.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 그러니 야채는 드시네요
# 교정본: 그래서 야채는 드시네요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 편의점 많지
# 교정본: 편의점 많지 편의점 많지.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 입 잘 따고 하시길래 야채도 안 먹었어요 진짜로
# 교정본: 입 잘 따고 하시길래 야채도 안 먹었어요 진짜로.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 야채는 먹어요 원래 안 먹었는데
# 교정본: 야채는 먹어요 원래 안 먹었는데.
# --------------------
# 원본  : 먹어야겠더라구요
# 교정본: 배고파 먹어야겠더라고요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저도 그러고 있어요
# 교정본: 저도 그러고 있어요.
# --------------------
# 원본  : 야채하고 과일
# 교정본: 아 야채하고 과일.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 과일은 원래 항상 좋아
# 교정본: 아 근데 과일은 원래 항상 좋아.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 혼자 살면 잘 안 먹게 되지 않아요?
# 교정본: 님은 혼자 살면 잘 안 먹게 되지 않아요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 동가가 진짜 엄청 많고
# 교정본: 동가가 진짜 엄청 많고.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 고댄찌개집 갔으면 저 슬플 뻔 했잖아요 성현님
# 교정본: 고댄찌개집 갔으면 저 슬플 뻔했잖아요 성현 님.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 고댄찌개집 갔으면 저 슬플 뻔 했잖아요
# 교정본: 고댄찌개집 갔으면 저 슬플 뻔했잖아요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 고댄찌개 가다고 했나요 제가?
# 교정본: 고댄찌개 가다고 했나요 제가?.
# --------------------
# 원본  : 처음에
# 교정본: ᄒᄒᄒᄒ 처음에.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아니 지금 얼굴에 웃음이 끊이지가 않으세요
# 교정본: 아니 지금 얼굴에 웃음이 그치지가 않으세요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 본가가 못 가요?
# 교정본: 본가가 못 가요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 뭘 못 가요?
# 교정본: 뭘 못 가요?.
# --------------------
# 원본  : 본가요
# 교정본: ᄏᄏᄏᄏᄏᄏᄏᄏ 본가요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 왜 못 가요?
# 교정본: 왜 못 가요?.
# --------------------
# 원본  : 멀어서
# 교정본: 멀어서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 갈 때마다 본가 갈 때 가요
# 교정본: 갈 때마다 본가 갈 때 가요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 본가 갈 때마다 먹어야죠
# 교정본: 본가 갈 때마다 먹어야죠.
# --------------------
# 원본  : 지금 좋은데 먹어요
# 교정본: 지금 좋은 데 먹어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 과일은 원래 더 안 먹어요
# 교정본: 과일은 원래 더 안 먹어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 본가 가면 거의 집에 과일이 많아서
# 교정본: 본가 가면 거의 집에 과일이 많아서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 1년에 한두 번 밖에 안 가요
# 교정본: 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번밖에 안 가요 1년에 한두 번
# --------------------
# 원본  : 왜요?
# 교정본: 왜요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저도 한두 번 밖에 안 가서 할만해요
# 교정본: 저도 한두 번밖에 안 가서 할 만해요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 거리가 머시니까 조금더
# 교정본: 님은 거리가 머시니까 조금 더.
# --------------------
# 원본  : 얼마있죠?
# 교정본: 님은 얼마 있죠?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 마치 차타요
# 교정본: 아 마치 차 타요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 차타가 어디에요?
# 교정본: 근데 차타가 어디예요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 차타가 30분이어서
# 교정본: 차타가 30분이어서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아 그럼 자주 와야겠다
# 교정본: 아 그럼 자주 와야겠다.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 귀찮은데 안오면 껍껍해하셔서 가요
# 교정본: 귀찮은데 안 오면 껍껍해하셔서 가요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 전화 자주하면 그만하래요
# 교정본: 전화 자주 하면 그만하래요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 얼마나 자주 하세요 지금?
# 교정본: 얼마나 자주 하세요 지금?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 2-3일 한 번씩 했더니 자주 아니면 그만하래
# 교정본: 2 3일 한 번씩 했더니 자주 아니면 그만하래.
# --------------------
# 원본  : 할 말 없겠네
# 교정본: 할 말 없겠네.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 그냥 안부전화가
# 교정본: 그냥 안부 전화가.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 밥 먹었나? 밥 먹었대요
# 교정본: 님은 밥 먹었나? 밥 먹었대요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 오늘 뭐했는데? 오늘 뭐 회사 갔다왔지 끝
# 교정본: 오늘 뭐 했는데? 오늘 뭐 회사 갔다 왔지 끝.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 밥 뭐 먹었는데?
# 교정본: 님은 밥 뭐 먹었는데?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 나 집에 있는거 먹어봤다
# 교정본: 나 집에 있는 거 먹어 봤다.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 집에 있는거 뭐 먹었냐?
# 교정본: 님은 집에 있는 거 뭐 먹었냐?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 엄마랑 딸이 치전데
# 교정본: 엄마랑 딸이 치전데.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 원래 반대로 물어보는게 맞지?
# 교정본: 원래 반대로 물어보는 게 맞지?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 바뀌었어요 엄마 바뀌어서
# 교정본: "엄마 바뀌어서" 바뀌었어요 엄마 바뀌어서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 집에 일찍 가라 해서
# 교정본: "집에 일찍 가라" 해서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 사람이 외동이라고 하시네
# 교정본: 외동이라고 하시네.
# --------------------
# 원본  : 아니요 오빠 하나 있어요
# 교정본: 아니요 오빠 하나 있어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 봐주실래요?
# 교정본: 님은 봐 주실래요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 오빠는 못봐 보네
# 교정본: 오빠는 못 봐 보네.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 오빠랑 사이 안좋아요
# 교정본: 오빠랑 사이 안 좋아요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아니요 안좋은데 좋아요
# 교정본: 아니요 안 좋은데 좋아요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 뭔지 알아요?
# 교정본: 님은 뭔지 알아요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 냄새가 안나요
# 교정본: 냄새가 안 나요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 실수 따까리
# 교정본: hate-speech.
# --------------------
# 원본  : 형 있어요?
# 교정본: 형 있어요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저도 동네인데 저는 성격이 더러워서
# 교정본: 저도 동네인데 저는 성격이 더러워서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 뭘 시키면 싸웠어요
# 교정본: 뭘 시키면 싸웠어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 너도 오빠 있어요?
# 교정본: 님도 너도 오빠 있어요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 따까리에요?
# 교정본: hate-speech예요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아니요 오빠랑 안 친해요
# 교정본: 아니요 오빠랑 안 친해요.
# --------------------
# 원본  : 아 짱 맛있어
# 교정본: 아 짱 맛있어.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 그냥 명절이나 이벤트 때 보는 사람 아니에요?
# 교정본: 그냥 명절이나 이벤트 때 보는 사람 아니에요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 맞아요
# 교정본: 맞아요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 사실 형도 주식하고 저도 그러고 있으니까
# 교정본: 아 근데 사실 형도 주식하고 저도 그러고 있으니까.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 거의 안 만나시던데요
# 교정본: 님 거의 안 만나시던데요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 1년에 한 번?
# 교정본: 1년에 한 번?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 두 번? 그렇게 안 만나요
# 교정본: 두 번? 그렇게 안 만나요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 형 일본이 있어요
# 교정본: 일본 일본이 있어요 근데 형 일본이 있어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 일본은 그냥 음식이 다 맛있던데요 저는
# 교정본: 일본은 그냥 음식이 다 맛있던데요 저는.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저도 좀 그런거 같아요
# 교정본: 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거 같아요 저도 좀 그런 거
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 저희 형도 입이 좀 까다로워서
# 교정본: 근데 저희 형도 입이 좀 까다로워서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저는 진짜 아무거나 준비를 못하거든요
# 교정본: 저는 진짜 아무거나 준비를 못 하거든요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 형이 좀 까다로워가지고
# 교정본: 형이 좀 까다로워 가지고.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 알아서 맛집 차려놓고 직접 끌고 다닙니다
# 교정본: 알았어 알아서 맛집 차려놓고 직접 끌고 다닙니다.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 여러분 김말이 매워요?
# 교정본: 님은 여러분 김말이 매워요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 그렇게 안 매워
# 교정본: 그렇게 안 매워.
# --------------------
# 원본  : 질려가지고
# 교정본: 질려 가지고.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 뭐 드세요?
# 교정본: 뭐 드세요?.
# --------------------
# 원본  : 매운 걸 잘 못 먹어요
# 교정본: 매운 걸 잘 못 먹어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 음...
# 교정본: 음.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 인생 절반쯤 해보자
# 교정본: 인생 절반쯤 해보자.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 4세트 김치 진짜 맛있어
# 교정본: 우리 4세트 김치 진짜 맛있어.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 진짜 진짜 짱 맛있어
# 교정본: 진짜 진짜 짱 맛있어.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 뭐가 맛있다고요?
# 교정본: 고요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 완전 상쾌해
# 교정본: 완전 상쾌해.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아침에 도랑매 안 드시길래 밥 끓인 줄 알았어요
# 교정본: 아침에 도랑매 안 드시길래 밥 끓인 줄 알았어요.
# --------------------
# 원본  : 저도
# 교정본: 저도 저도.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 밥 끓인 줄 알았어요
# 교정본: 밥 끓인 줄 알았어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 약속이 취소되는지 알았나봐요
# 교정본: 약속이 취소되는지 알았나 봐요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 오후에 다 갔다 와야 돼가지고
# 교정본: 2시 반에 다 갔다 와야 돼가지고 오후에 다 갔다 와야 돼가지고 오후에 다 갔다 와야 돼가지고 오후에 다 갔다 와야 돼가지고 오후에 다 갔다 와야 돼가지고 오후에 다 갔다 와야 돼가지고 오후에 다 갔다 와야 돼가지고 오후에 다 갔다 와야 돼가지고 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에 다 갔다 와야 돼서 오후에
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 도랑님 늦으신 거 한 번도 못 본 거 같은데
# 교정본: 늦으신 거 한 번도 못 본 거 같은데.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 예전에 늦게 왔어요
# 교정본: 예전에 늦게 왔어요.
# --------------------
# 원본  : 아 그래요?
# 교정본: 아 그래요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 나왔는데 집에 투명점을 주고 온 거
# 교정본: 나왔는데 집에 투명점을 주고 온 거.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저한테 치는 거죠
# 교정본: 저한테 치는 거죠.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 전 집에 있는 것도 좋아해요
# 교정본: 전 집에 있는 것도 좋아해요.
# --------------------
# 원본  : 네 감사하세요
# 교정본: 네 감사하세요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 대게요?
# 교정본: 대게요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아 해외요?
# 교정본: 아 해외요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 다 말을 못 알아듣지. 내가 말하면 된다.
# 교정본: "다 말을 못 알아듣지?" 내가 말하면 된다.
# --------------------
# 원본  : 운이 없어 봐.
# 교정본: 운이 없어 봐.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저도 형이 계속 일본 오라고 하는데 운이 없어 봐.
# 교정본: 저도 형이 계속 일본 오라고 하는데 운이 없어 봐.
# --------------------
# 원본  : 맞아요.
# 교정본: 맞아요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 비행기를 좀 무서워해서.
# 교정본: 비행기를 좀 무서워해서.
# --------------------
# 원본  : 비행기 무서워요.
# 교정본: 비행기 무서워요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 그럼 해외항 가보세요.
# 교정본: 그럼 해외항 가 보세요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 비행기 타고 갔는데 비행기 탈 때 청시만 먹었어요.
# 교정본: 이는 비행기 타고 갔는데 비행기 탈 때 청시만 먹었어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 비행기 타가지고 일단 서울 왔다 갔다 보니까 비행기가 더 싸요.
# 교정본: 님도 비행기 타 가지고 일단 서울 왔다 갔다 보니까 비행기가 더 싸요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 진짜 국내에서는 한 번도 안 타봤는데.
# 교정본: 진짜 국내에서는 한 번도 안 타봤는데.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 동네에서 만드셨나요?
# 교정본: 님은 동네에서 만드셨나요?.
# --------------------
# 원본  : 네, 만드셨어요
# 교정본: 네 만드셨어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 저는 지금 공항 앞이어서
# 교정본: 저는 지금 공항 앞이어서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 위에서 많이 못 먹어서 너무 슬퍼요
# 교정본: 님 위에서 많이 못 먹어서 너무 슬퍼요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 안 먹으면 되죠
# 교정본: 안 먹으면 되죠.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 배불러서요?
# 교정본: 배불러서요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 약간 병원 가야겠다
# 교정본: ᄒᄒ 약간 병원 가야겠다.
# --------------------
# ...
# 원본  : 왜 이렇게 열받지?
# 교정본: 왜 이렇게 열받지?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 관리를 해서 살이 다 빼진 거죠
# 교정본: 님은 관리를 해서 살이 다 빼진 거죠.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아니 너무 말리셨길래
# 교정본: 아니 너무 말리셨길래.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저거 드셔야 되는 거 아니에요?
# 교정본: 님은 저거 드셔야 되는 거 아니에요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아니 먹어요
# 교정본: 아니 먹어요 아니 먹어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 문자 사신 적 있나요?
# 교정본: 문자 사신 적 있나요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저는 지금은 부모님이랑이에요
# 교정본: 저는 지금은 부모님이랑이에요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저희도 자취할 때 노래 맞죠?
# 교정본: 저희 저희도 자취할 때 노래 맞죠?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 바비 같은 거 재세요?
# 교정본: 바비 같은 거 재세요?.
# --------------------
# 원본  : 우리는 못 재세요
# 교정본: 우리는 못 재세요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 그래요?
# 교정본: 그래요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 그리고 다 씨는 아니에요
# 교정본: hate-speech 그리고 다 씨는 아니에요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 씨 아니에요?
# 교정본: hate-speech 아니에요?.
# --------------------
# 원본  : 이렇게?
# 교정본: 이렇게?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 이런 느낌?
# 교정본: 님은 이런 느낌?.
# --------------------
# 원본  : 나오려다가
# 교정본: 오려다가 나오려다가.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 식성률 몇 퍼일 거 같은데
# 교정본: 식성률 몇 퍼일 거 같은데.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 이게 남자랑 여자랑 좀 다르다고
# 교정본: hate-speech 근데 이게 남자랑 여자랑 좀 다르다고.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 남자는 15%일까?
# 교정본: hate-speech 남자는 10%일까?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 그게 평균인가요?
# 교정본: 그게 평균인가요?.
# --------------------
# 원본  : 건강한 분
# 교정본: 님은 건강한 분.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 평균은 아니고
# 교정본: 평균은 아니고.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 여성분들이어야지 이제
# 교정본: 님은 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이어야지 이제 여성분들이
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 건강하다? 여자는? 20%?
# 교정본: 님은 건강하다? 여자는? 20%?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 여성분들은 남성분보다 좀 많이 높다고 해서
# 교정본: 님은 여성분들은 남성분보다 좀 많이 높다고 해서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 20 몇 퍼 아니에요?
# 교정본: 20 몇 퍼 아니에요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 저 몇 퍼일 것 같아요?
# 교정본: 저 몇 퍼일 것 같아요?.
# --------------------
# 원본  : 뭘까요?
# 교정본: 님은 뭘까요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 팔씨끌어내
# 교정본: hate-speech 끌어 내.
# --------------------
# 원본  : 죄송합니다
# 교정본: 님도 죄송합니다.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아 나 다리를 얘기 안했잖아
# 교정본: 아 나 다리를 얘기 안 했잖아.
# --------------------
# 원본  : 아직
# 교정본: ᄏᄏᄏᄏᄏ 아직 아직.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 살 생활에서 반말을 못하네
# 교정본: 살 생활에서 반말을 못 하네.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 주영이 운동하세요?
# 교정본: 주영이 운동하세요?.
# --------------------
# 원본  : 아니요
# 교정본: 아니요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 너무 놀래던데
# 교정본: 너무 놀래던데.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아 근데 저는 여자들 기준을 몰라서
# 교정본: 아 근데 저는 여자들 기준을 몰라서.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 근데 그거 나 지금 녹음 됐는 줄 알아요?
# 교정본: 님은 그거 나 지금 녹음됐는 줄 알아요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 이거 학습에 쓰이나요?
# 교정본: 이거 학습에 쓰이나요?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 아니 학습 말고
# 교정본: "아니 학습 말고" 아니 학습 말고.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 그냥 우리 지금 모델 정하는 데 쓰고 있어요
# 교정본: 그냥 우리 지금 모델 정하는 데 쓰고 있어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 학습에 쓰지는 말아주세요
# 교정본: 학습에 쓰지는 말아 주세요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 왜요? 누구 뒷담화 들어갔어요 또?
# 교정본: 님은 왜요? 누구 뒷담화 들어갔어요 또?.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 이제 퍼스널 신체 정보가 들어갔습니다
# 교정본: 이제 퍼스널 신체 정보가 들어갔습니다.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 기훈님 개인정보가 들어갔어요
# 교정본: 기훈 님 개인 정보가 들어갔어요.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 마스킹 처리 해드릴게요
# 교정본: 마스킹 처리해 드릴게요.
# --------------------
# 원본  : 감사합니다
# 교정본: 감사합니다.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 배불러요 하면서 계속 드시고 있는데
# 교정본: "배불러요" 하면서 계속 드시고 있는데.
# --------------------
# Both `max_new_tokens` (=256) and `max_length`(=256) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 원본  : 기훈님 배불러요? 배불러요?
# 교정본: 기훈 님 배불러요? 배불러요?.
# --------------------
# 원본  : 40분 정도면 충분하겠죠?
# 교정본: ? 40분 정도면 충분하겠죠?.
# --------------------
#
# 5개 샘플 처리 완료 (소요 시간: 169.89초)
